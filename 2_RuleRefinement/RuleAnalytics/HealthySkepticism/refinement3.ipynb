# %% [markdown]
# ## Rule Refinement Template Notebook:
#
# In this notebook, it is assumed that data has been mined from twitter and is present in a JSON format, in a local file.
#
# This notebook will separate all tweets by tag, and then run sub-section analysis on each of the tag dataframes.
#
# Users must manually look through the tweets (sadly), and classify what "good" and "bad" tweets are.
#
# Using simple data tidying, and intuitive methods (set difference between tokenized strings of "good and bad" tweets), we attempt to provide information to the user to properly refine their rules, and evaluate recent adjustments to their rules.

# %%
#Load our custom library. Ouputs files in local directory automatically.
from mods.dfprocess import *
pd.set_option('display.max_rows', 500)
# Out:
# ['ProposedRules.txt', 'test6rules.twts', 'mergefile_r1-6_2.twts', 'exampletweets.txt', 'test6rules4.twts', 'test6rules2.twts', 'test6rules3.twts', 'selectedtweets.json', 'mergedfile_rule1-6.twts']

# %%
tweetDF = generatedataframe("./data/mergefile_r1-6_2.twts",10000)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5088 entries, 0 to 5087
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tweetid        5088 non-null   int64
#  1   text           5088 non-null   object
#  2   created_at     5088 non-null   object
#  3   tagid          5088 non-null   int64
#  4   tag            5088 non-null   object
#  5   userid         5088 non-null   int64
#  6   username       5088 non-null   object
#  7   rtcount        5088 non-null   int16
#  8   repcount       5088 non-null   int16
#  9   likecount      5088 non-null   int16
#  10  qtcount        5088 non-null   int16
#  11  tweet_type     5088 non-null   object
#  12  ref_tweetid    5088 non-null   int64
#  13  ref_authorid   5088 non-null   int64
#  14  ref_rtcount    5088 non-null   int16
#  15  ref_repcount   5088 non-null   int16
#  16  ref_likecount  5088 non-null   int16
#  17  ref_qtcount    5088 non-null   int16
# dtypes: int16(8), int64(5), object(5)
# memory usage: 477.1+ KB

# %%
tweetDF = cleanDF(tweetDF)
tweetDF.drop_duplicates(subset=["text"],inplace=True)
tweetDF = tweetDF[tweetDF['text'].astype(bool)]

# %%
#Get tags with: (dF.tag.unique()).tolist()
saiDF = getTagDF("HealthySkepticism", "./data/selectedtweets.json",tweetDF)

# %%
#Now set your good tweets. Look through the outputted file manually.
goodTweets = [108,117,13,125,140,185,200,227,274]

# %%
#The main part of the show.
gDict = {}
bDict = {}
gSet = set()
bSet = set()

hold = setdiffprocess(saiDF,goodTweets,gSet,gDict,bSet,bDict)

# %%
#Set operations
goodWords = gSet.difference(bSet)
badWords = bSet.difference(gSet)
intWords = gSet.intersection(bSet)

# %%
#Display Top Words
disp_topwords(badWords,bDict,50)
# Out:
#                  word  count
# 1450             like     47
# 921              what     43
# 2578            their     39
# 125              from     38
# 3129             when     29
# 1118       persuasion     28
# 2607             more     26
# 2219          fallacy     23
# 570            spread     21
# 2431             it's     20
# 15              first     19
# 2397           trying     17
# 1910           really     17
# 1931             know     15
# 1511           should     14
# 2729             does     14
# 1853             into     13
# 2877             most     13
# 2720             real     13
# 1710             been     13
# 536              some     13
# 2542          nudging     12
# 548             being     12
# 1762             make     12
# 988              need     12
# 623         something     11
# 881              over     11
# 775              very     11
# 1970           hustle     11
# 1413             then     11
# 2449           things     10
# 466              even     10
# 1603         actually     10
# 1587             only     10
# 1490             them     10
# 72             person      9
# 2764       skepticism      9
# 1628             well      9
# 1462           become      9
# 426              work      9
# 1695        lobbyists      9
# 2815             news      9
# 1357  misinformation.      9
# 427             where      9
# 2033          twitter      9
# 1084             want      8
# 163          business      8
# 2719         anything      8
# 942              good      8
# 1593            force      8

# %%
disp_topwords(intWords,gDict,50)
# Out:
#               word  count
# 82            with      5
# 27            much      4
# 3             love      3
# 34         without      3
# 80            that      2
# 28           there      2
# 61            just      2
# 56            time      2
# 40            your      2
# 23         nothing      2
# 53            they      2
# 83           &amp;      2
# 4   misinformation      2
# 54           away.      1
# 65         believe      1
# 52            task      1
# 57         skeptic      1
# 58         doesn't      1
# 59            than      1
# 51         there’s      1
# 60            it’s      1
# 62          people      1
# 63      convincing      1
# 64           cause      1
# 50            also      1
# 55           hand,      1
# 0             have      1
# 66          normal      1
# 67           life,      1
# 86            less      1
# 85        complete      1
# 84         between      1
# 81            hate      1
# 79          living      1
# 78  disinformation      1
# 77           media      1
# 76        planning      1
# 75           after      1
# 74         totally      1
# 73            free      1
# 72            long      1
# 71         someone      1
# 70           can't      1
# 69           lies,      1
# 68            term      1
# 48         journey      1
# 49            you.      1
# 44           still      1
# 47           think      1
# 46           often      1

# %% [markdown]
# **Conclusion:**Not many changes to make. I will remove "fallacies" and "Persuasion", as a lot
#     of these takes just point out a particular mistake in reasoning or talk about marketing tactics..They
#     are quite boring.
