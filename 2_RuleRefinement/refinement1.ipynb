# %% [markdown]
# ## Rule Refinement Template Notebook:
#
# In this notebook, it is assumed that data has been mined from twitter and is present in a JSON format, in a local file.
#
# This notebook will separate all tweets by tag, and then run sub-section analysis on each of the tag dataframes.
#
# Users must manually look through the tweets (sadly), and classify what "good" and "bad" tweets are.
#
# Using simple data tidying, and intuitive methods (set difference between tokenized strings of "good and bad" tweets), we attempt to provide information to the user to properly refine their rules, and evaluate recent adjustments to their rules.

# %%
#Load our custom library. Ouputs files in local directory automatically.
from mods.dfprocess import *
pd.set_option('display.max_rows', 500)

# %%
tweetDF = generatedataframe("./data/sept9_rule1-4.twts",5000)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1664 entries, 0 to 1663
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tweetid        1664 non-null   int64
#  1   text           1664 non-null   object
#  2   created_at     1664 non-null   object
#  3   tagid          1664 non-null   int64
#  4   tag            1664 non-null   object
#  5   userid         1664 non-null   int64
#  6   username       1664 non-null   object
#  7   rtcount        1664 non-null   int16
#  8   repcount       1664 non-null   int16
#  9   likecount      1664 non-null   int16
#  10  qtcount        1664 non-null   int16
#  11  tweet_type     1664 non-null   object
#  12  ref_tweetid    1664 non-null   int64
#  13  ref_authorid   1664 non-null   int64
#  14  ref_rtcount    1664 non-null   int16
#  15  ref_repcount   1664 non-null   int16
#  16  ref_likecount  1664 non-null   int16
#  17  ref_qtcount    1664 non-null   int16
# dtypes: int16(8), int64(5), object(5)
# memory usage: 156.1+ KB

# %%
tweetDF = cleanDF(tweetDF)
tweetDF.drop_duplicates(subset=["text"],inplace=True)
tweetDF = tweetDF[tweetDF['text'].astype(bool)]

# %%
#(tweetDF.tag.unique()).tolist()
saiDF = getTagDF("HealthySkepticism", "./data/selectedtweets.json",tweetDF)

# %%
#Now set your good tweets. Look through the outputted file manually.
goodTweets = [28,36,37,55,57,71,119,132,151,154,156]

# %%
#The main part of the show.
gDict = {}
bDict = {}
gSet = set()
bSet = set()

hold = setdiffprocess(saiDF,goodTweets,gSet,gDict,bSet,bDict)

# %%
#Set operations
goodWords = gSet.difference(bSet)
badWords = bSet.difference(gSet)
intWords = gSet.intersection(bSet)

# %%
#Display Top Words
disp_topwords(badWords,bDict,50)
# Out:
#                  word  count
# 338             queen     29
# 1120        spreading     17
# 1051             your     15
# 995              stop     14
# 309              from     11
# 311              need     10
# 753              even     10
# 1387             some     10
# 510            please      9
# 413              will      9
# 624              been      9
# 1256       persuasion      9
# 1428            media      8
# 994             don't      7
# 1130             know      7
# 7               being      7
# 24           internet      7
# 463             going      6
# 1219          talking      6
# 1001             guys      6
# 774              most      6
# 1182            there      6
# 711         followers      6
# 578             still      6
# 1092             next      5
# 194              into      5
# 468           fallacy      5
# 472            saying      5
# 1242           should      5
# 813              life      5
# 896           content      5
# 120      influencers,      5
# 941             right      5
# 1457            other      5
# 161         political      5
# 1388  misinformation.      5
# 839              dead      5
# 300           getting      5
# 942              want      5
# 158             while      4
# 964             isn't      4
# 747            system      4
# 512              keep      4
# 507            skills      4
# 180         something      4
# 508             doing      4
# 59              don’t      4
# 1073             very      4
# 931             never      4
# 1108            would      4

# %% [markdown]
# **Conclusion:** I see the following words are associated with negative tweets: spreading, stop, please. I still want the misinformation tweets, so I don't screen that word. Mainly, "plea" like tweets will be ignored.

# %%
goodWords
# Out:
# {'"adventures",',
#  "'naturalistic",
#  "'well",
#  'actually',
#  'all,',
#  'amplifiers',
#  'anti-woke',
#  'anybody',
#  "anyone's",
#  'arguments',
#  'band',
#  'belonging',
#  'biases,',
#  'blogs',
#  'bozo',
#  'braindead',
#  'cards',
#  'circle.',
#  'club',
#  'confirms',
#  'correct',
#  'credit',
#  'culture;',
#  'discourse',
#  'displays',
#  'drowned',
#  'drug',
#  'dull',
#  'enemy',
#  'enforcing',
#  'equally.',
#  'equitable',
#  'evopsych',
#  'explaining',
#  'exposure.',
#  'exposures',
#  "fallacy'",
#  'fallacy-ridden',
#  'fallacy.\nnarcissus',
#  'fighting.',
#  'flood',
#  'force',
#  "good'",
#  'hearing',
#  'himself.',
#  'hoes.',
#  'identify',
#  'ideology',
#  'information.',
#  'lame',
#  'lends',
#  "man's",
#  'memes',
#  'metaphorical',
#  'midwit-borne',
#  'misinform',
#  'misinformation,',
#  'moderation',
#  'moral',
#  'myelin',
#  'narcissists',
#  'narratives',
#  'night',
#  "one's",
#  'others.',
#  'outcomes',
#  'outsource',
#  'painting',
#  'peeve',
#  'plan.',
#  'pretend',
#  'productive',
#  'promiscuity',
#  'promiscuous',
#  'prone',
#  'pull',
#  'quote',
#  'reflected-self.',
#  'reflection.\nthere',
#  'repairs',
#  'respond',
#  'routinely',
#  'said',
#  'scared',
#  'scores',
#  'self',
#  'sell',
#  'sheathe',
#  'side-hustle',
#  'sound',
#  'speech',
#  'systems,',
#  'tells',
#  'themselves.\nbut',
#  'theorycrafting',
#  'thinking',
#  'thus',
#  'time;',
#  'towards',
#  'tribal',
#  'tribe.',
#  'unfortunate',
#  'unscrupolous',
#  'wanted',
#  'wedding…',
#  'whippets',
#  'whole',
#  'woke.',
#  'women,',
#  'worth'}
